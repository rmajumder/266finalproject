# %%
import pandas as pd
import numpy as np
import spacy
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
from spacy import displacy
import json
import random
import re

# %%
df_orginal_android = pd.read_excel('./data/qb/original/android.xlsx')

# %%
len(df_orginal_android)
# Out:
# 12281

# %%
df_orginal_android.head()

# %%
#Import original data
df_orginal_ios = pd.read_excel('./data/qb/original/ios.xlsx')

# %%
df_orginal_ios.head()

# %%
df_orginal = df_orginal_ios.append(df_orginal_android, ignore_index=True)

# %%
#Get selective columns

df = df_orginal[['Review ID','Country', 'Version', 'Rating', 'Date', 'Subject', 'Body', 'Sentiment']]

# %%
df.head()

# %%
df['Subject'] = df['Subject'].replace(np.nan, '', regex=True)
df['Body'] = df['Body'].replace(np.nan, '', regex=True)

# %%
df.head()

# %%
len(df)

# %%
#combine subject and body
#df['Review'] = df[['Subject', 'Body']].apply(lambda x: '. '.join(x), axis=1)

for index, row in df.iterrows():
    sub = row['Subject']
    body = row['Body']
    
    df.loc[index,'Review'] = str(sub) + ". " + str(body)

# %%
df.head()

# %%
#Drop Subject and Body

del df['Subject']
del df['Body']

# %%
df.head()

# %%
filename = "./data/qb/processed/train_ner.json"
print(filename)


with open(filename) as train_data:
    train = json.load(train_data)

TRAIN_DATA_NEW = []
for data in train:
    ents = [tuple(entity) for entity in data['entities']]
    TRAIN_DATA_NEW.append((data['content'],{'entities':ents}))


with open('{}'.format(filename.replace('json','txt')),'w') as write:
    write.write(str(TRAIN_DATA_NEW))
# Out:
# ./data/qb/processed/train_ner.json

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.load('en_core_web_sm')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
    else:
        ner = nlp.get_pipe("ner")
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
    return nlp


prdnlp = train_spacy(TRAIN_DATA_NEW, 20)
# Out:
# Statring iteration 0
# {'ner': 2026.224508466591}
# Statring iteration 1
# {'ner': 2028.0348857634299}
# Statring iteration 2
# {'ner': 1888.9462946534277}
# Statring iteration 3
# {'ner': 2158.9921128757787}
# Statring iteration 4
# {'ner': 1980.4446047670474}
# Statring iteration 5
# {'ner': 2100.2030422435587}
# Statring iteration 6
# {'ner': 1918.9685051096747}
# Statring iteration 7
# {'ner': 1965.7143093003533}
# Statring iteration 8
# {'ner': 1842.3065502064946}
# Statring iteration 9
# {'ner': 1920.9444526238128}
# Statring iteration 10
# {'ner': 1868.9978669467166}
# Statring iteration 11
# {'ner': 1948.4514279842679}
# Statring iteration 12
# {'ner': 1936.9918960441307}
# Statring iteration 13
# {'ner': 1906.0687236476688}
# Statring iteration 14
# {'ner': 1847.6175456084263}
# Statring iteration 15
# {'ner': 1940.7462582741741}
# Statring iteration 16
# {'ner': 1810.2830493400627}
# Statring iteration 17
# {'ner': 1905.0144225298377}
# Statring iteration 18
# {'ner': 1927.987444192847}
# Statring iteration 19
# {'ner': 1784.5002934570007}

# %%
# Save our trained Model
prdnlp.to_disk("./model/qbo_aspect")

# %%
#Test your text
test_text = ["Cancelling your subscription seems impossible. I've emailed, called, used their help menu. It shouldn't be this hard. Still trying to cancel.",
              "My App has stopped working on my Samsung s9 for 2 days in a row. You should have sent an email to inform subscribers if your app is going to be experiencing a downtime.",
              "Cannot open customer invoices. Please correct ASAP!",
               "bugs on iOS13 please update ASAP!"]
for text in test_text:
    print('-----')
    doc = prdnlp(text)
    for ent in doc.ents:
        print('keyword=' + ent.text, 'aspect=' + ent.label_)
# Out:
# -----
# keyword=subscription aspect=Subscription
# keyword=hard aspect=Experience
# -----
# keyword=App aspect=App
# -----
# keyword=invoices aspect=Invoicing
# -----
# keyword=bugs aspect=Experience
# keyword=update aspect=Updates

# %%
for index, row in df.iterrows():
    aspect_terms = []
    aspect_related_text = []
    doc = prdnlp(row['Review'])
    for ent in doc.ents:
        if ent.label_ not in aspect_terms:            
            aspect_terms.append(ent.label_)
            aspect_related_text.append(str(ent))

    df.loc[index,'Aspects'] = ", ".join(aspect_terms)
    df.loc[index,'AspectText'] = ", ".join(aspect_related_text)

# %%
df.head()
# Out:
#       Review ID Country  Version  Rating       Date Sentiment  \
# 0  5.467988e+09     USA  20.01.6       1 2020-01-31  negative
# 1  5.464235e+09  Canada  20.01.5       1 2020-01-30  negative
# 2  5.467098e+09     USA  20.01.5       3 2020-01-30  negative
# 3  5.466985e+09     USA  20.01.5       5 2020-01-30  positive
# 4  5.467691e+09     USA  20.01.6       5 2020-01-30  positive
#
#                                               Review  \
# 0  Shiny useless tool. This app looks awesome.  V...
# 1  Latest app update. This update is terrible bas...
# 2  App closes out while entering expenses. The ma...
# 3  Life saver. One my favorite apps to use while ...
# 4  Small business. This absolutely works perfectl...
#
#                                  Aspects                      AspectText
# 0  App, Expenses, Help, Customer Service  app, expenses, videos, support
# 1                                    App                             app
# 2        App, Transactions, Subscription  App, transaction, subscription
# 3                                    App                            apps
# 4

# %%
#number of reviews without aspect
(df['Aspects'].values == '').sum()
# Out:
# 7193

# %%
len(df)
# Out:
# 19841

# %%
df['Aspects'].replace('', np.nan, inplace=True)
df.dropna(subset=['Aspects'], inplace=True)
# Out:
# /home/rmajumder/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /home/rmajumder/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(df)
# Out:
# 12648

# %%
df.head(50)
# Out:
#       Review ID         Country  Version  Rating       Date Sentiment  \
# 0   5.46799e+09             USA  20.01.6       1 2020-01-31  negative
# 1   5.46424e+09          Canada  20.01.5       1 2020-01-30  negative
# 2    5.4671e+09             USA  20.01.5       3 2020-01-30  negative
# 3   5.46699e+09             USA  20.01.5       5 2020-01-30  positive
# 5   5.46055e+09             USA  20.01.4       1 2020-01-29  negative
# 6   5.46148e+09             USA  20.01.4       1 2020-01-29  negative
# 7   5.46253e+09             USA  20.01.4       5 2020-01-29  positive
# 8   5.46281e+09             USA  20.01.4       4 2020-01-29     mixed
# 10  5.45735e+09  United Kingdom  20.01.4       4 2020-01-28   neutral
# 11  5.45882e+09             USA  20.01.4       3 2020-01-28  negative
# 14  5.45424e+09             USA  20.01.3       3 2020-01-27  negative
# 15   5.4564e+09       Australia  20.01.4       5 2020-01-27  positive
# 16  5.45002e+09  United Kingdom  19.10.1       3 2020-01-26  negative
# 17  5.45115e+09             USA  20.01.3       2 2020-01-26  negative
# 18  5.45206e+09             USA  20.01.3       3 2020-01-26  negative
# 19  5.45201e+09             USA  20.01.3       1 2020-01-26  negative
# 20  5.44771e+09             USA  20.01.3       1 2020-01-25  negative
# 21  5.44849e+09             USA  20.01.3       1 2020-01-25  negative
# 22  5.44074e+09             USA  20.01.3       2 2020-01-24  negative
# 23  5.44324e+09          Canada  20.01.3       1 2020-01-24  negative
# 25  5.44447e+09             USA  20.01.3       3 2020-01-24  negative
# 26  5.43681e+09             USA  20.01.3       2 2020-01-23  negative
# 29  5.43922e+09             USA  20.01.3       1 2020-01-23  negative
# 30  5.43566e+09  United Kingdom  20.01.3       1 2020-01-22  negative
# 32   5.4268e+09             USA  20.01.3       1 2020-01-20  negative
# 33  5.42883e+09          Canada  20.01.3       1 2020-01-20  negative
# 34  5.42158e+09             USA  20.01.3       1 2020-01-19  negative
# 35  5.42343e+09          Canada  20.01.3       1 2020-01-19  negative
# 36  5.41686e+09             USA  20.01.2       1 2020-01-18  negative
# 38   5.4126e+09             USA  20.01.2       1 2020-01-17  negative
# 39   5.4151e+09             USA  20.01.2       2 2020-01-17   neutral
# 41  5.40896e+09             USA  20.01.2       1 2020-01-16  negative
# 42  5.40929e+09          Canada  20.01.2       1 2020-01-16  negative
# 43  5.40871e+09       Singapore  20.01.2       1 2020-01-16  negative
# 44  5.40488e+09             USA  20.01.1       4 2020-01-15   neutral
# 45  5.40698e+09             USA  20.01.1       1 2020-01-15  negative
# 46  5.40777e+09             USA  20.01.1       1 2020-01-15  negative
# 47  5.40036e+09             USA  20.01.0       1 2020-01-14  negative
# 48  5.40028e+09             USA  20.01.0       3 2020-01-14  positive
# 49  5.40401e+09             USA  20.01.1       1 2020-01-14  negative
# 50  5.40365e+09             USA  20.01.0       1 2020-01-14  negative
# 51  5.39903e+09       Australia  20.01.0       5 2020-01-13  positive
# 53  5.39452e+09             USA  20.01.0       1 2020-01-12  negative
# 54  5.38941e+09             USA  20.01.0       5 2020-01-11  positive
# 55  5.39043e+09             USA  20.01.0       5 2020-01-11     mixed
# 57  5.38589e+09  United Kingdom  20.01.0       4 2020-01-10     mixed
# 59  5.37983e+09             USA  20.01.0       5 2020-01-09  positive
# 60  5.38074e+09             USA  20.01.0       4 2020-01-09  positive
# 61  5.38225e+09             USA  20.01.0       5 2020-01-09  positive
# 62   5.3823e+09          Canada  20.01.0       5 2020-01-09  positive
#
#                                                Review  \
# 0   Shiny useless tool. This app looks awesome.  V...
# 1   Latest app update. This update is terrible bas...
# 2   App closes out while entering expenses. The ma...
# 3   Life saver. One my favorite apps to use while ...
# 5   Worst update yet. Just deleted. Crashed. Didn’...
# 6   Transferring to TurboTax. Transferring company...
# 7   Great app for small business owners!. I have a...
# 8   Good but needs multi currency. Very easy to us...
# 10  Good App but. It’s a good app but you should b...
# 11  Having issues with iPhone 11. After installing...
# 14  Newest update doesn’t load dashboard. Dashboar...
# 15  It just works. See above. \n\nIn the office, o...
# 16  It's ok but don't get the most basic package. ...
# 17  Terrible. This app has so many problems. It wi...
# 18  Not happy with new update. New update has made...
# 19  Latest update removed every feature I used. DO...
# 20                                Garbage. app stinks
# 21  The worst customer service ever. Don’t waist y...
# 22  Functional but HUGE gaps. It works and some pa...
# 23  Unable to Download. It keep saying you already...
# 25  App doesn’t open. App doesn’t open on the new ...
# 26  Functional but HUGE gaps. It works and some pa...
# 29  App is almost useless for me.. The only reason...
# 30  Terrible Support - AVOID. Terrible, terrible s...
# 32  One of the worst decisions ever!. I decided to...
# 33  Rates have doubled with no appreciable improve...
# 34  Stopped Working. Worked great until about 1 we...
# 35  Mileage tracker not working.. So far QuickBook...
# 36  Useless. Useless. Confusing and incomprehensible.
# 38  Don’t use this with an IPad.. Bought this app ...
# 39  Not Just Businesses. I completely understand t...
# 41  App notifications. App has issues which never ...
# 42  Can’t Upload receipts. It’s incredibly ridicul...
# 43           30 days trial. Need to pay after 30 days
# 44  Expense widget is not accurate. 1st let me say...
# 45  Horrible. Worst company and app to deal with. ...
# 46  Bad update. I was having trouble with the mile...
# 47  Bad update. Befoe you used to record bank feed...
# 48  Overall I recommend this app. I have a mobile ...
# 49  QB app is useless. Update \nQuickbooks refuses...
# 50  Mileage tracker, not working. I have emailed f...
# 51  Small Business. I have been using QB for two y...
# 53  Doesn’t sync with Quickbooks online account. T...
# 54  Amazing!. I have used everything but Quick boo...
# 55  Don’t use the pay options.. App is great but d...
# 57  Please add the option to enter bills. Having j...
# 59  Well thought out. Truly like the app now. I ca...
# 60  Very helpful.... There are some glitches with ...
# 61  So easy to do books on the go!. I cannot say e...
# 62  WOW!. Such an easy app to use as a new busines...
#
#                                               Aspects  \
# 0                                       App, Expenses
# 1                                        App, Updates
# 2             App, Expenses, Experience, Subscription
# 3                                                 App
# 5                                 Updates, Experience
# 6                                          Experience
# 7                                                 App
# 8                                           Invoicing
# 10                                     App, Invoicing
# 11                                                App
# 14                                          Dashboard
# 15                                                App
# 16                                                App
# 17                                       App, Quality
# 18                                Experience, Updates
# 19                Updates, App, Dashboard, Experience
# 20                                       Quality, App
# 21                                   Customer Service
# 22                    Receipt Capture, App, Invoicing
# 23                                            Quality
# 25                                                App
# 26                    Receipt Capture, App, Invoicing
# 29              App, Experience, Estimates, Invoicing
# 30                          Customer Service, Quality
# 32                                   Customer Service
# 33                                         Accountant
# 34                                         Experience
# 35                          Quality, Customer Service
# 36                                         Experience
# 38                                                App
# 39                                    App, Experience
# 41                         App, Invoicing, Experience
# 42                         Receipt Capture, Invoicing
# 43                                       Subscription
# 44                    Quality, App, Updates, Expenses
# 45                                         Experience
# 46                              Updates, Quality, App
# 47                                            Updates
# 48                                                App
# 49  App, Experience, Updates, Receipt Capture, Exp...
# 50                                   Customer Service
# 51                                                App
# 53                                       Quality, App
# 54                                         Experience
# 55                                                App
# 57                    Experience, Invoicing, Expenses
# 59                                                App
# 60                        Customer Service, Invoicing
# 61                                                App
# 62                                                App
#
#                                            AspectText
# 0                                   useless, expenses
# 1                                         app, update
# 2             App, expenses, department, subscription
# 3                                                apps
# 5                                     update, deleted
# 6                                               issue
# 7                                                 app
# 8                                             invoice
# 10                                      App, invoices
# 11                                                app
# 14                                          dashboard
# 15                                           software
# 16                                                app
# 17                                      app, problems
# 18                                      happy, update
# 19                    update, app, dashboard, useless
# 20                                       Garbage, app
# 21                                   customer service
# 22                     receipt matching, app, invoice
# 23                                           Download
# 25                                                App
# 26                     receipt matching, app, invoice
# 29                   App, useless, estimates, invoice
# 30                                      support, bugs
# 32                                   customer service
# 33                                               IPad
# 34                                       transactions
# 35                                   Mileage, support
# 36                                          Confusing
# 38                                                app
# 39                                        app, easier
# 41                        App, invoices, reinstalling
# 42                           Upload receipts, invoice
# 43                                              trial
# 44                    Expense, app, updates, expenses
# 45                                           Horrible
# 46                                   update, fix, app
# 47                                             update
# 48                                                app
# 49  app, useless, Update, iPad app, expenses, support
# 50                                            support
# 51                                            program
# 53                                       Doesn’t, app
# 54                                             easier
# 55                                                App
# 57                         easier, invoices, expenses
# 59                                                app
# 60                    customers efficiently, invoices
# 61                                                app
# 62                                                app

# %%
# !pip install afinn
# Out:
# Requirement already satisfied: afinn in /home/rmajumder/anaconda3/lib/python3.7/site-packages (0.1)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from afinn import Afinn
af = Afinn()

# %%
#generate aspect position index

def generate_df_with_position(data_frame):

    df_split_terms = pd.DataFrame(columns=['Review ID', 
                                           'Country', 'Version', 
                                           'Rating', 'Date', 'Doc Sentiment', 'Asp Sentiment', 
                                           'Review', 'Aspects', 'AspectText', 'Positions'])


    for index, row in data_frame.iterrows():
        aspecttexts = [x.strip() for x in row['AspectText'].lower().split(',')]
        aspects = [x.strip() for x in row['Aspects'].lower().split(',')]

        positions = ''
        for idx, asp in enumerate(aspecttexts):

            review = " ".join(row['Review'].lower().split())

            if len(review.split(' ')) > 85:
                continue

            start_idx = review.find(asp)

            #if the aspect is not found in the review, skip
            if start_idx == -1:
                continue

            sentiment = 'neutral' if row['Sentiment'] == 'mixed' else row['Sentiment']
            
            
            df_split_terms = df_split_terms.append({
                'Review ID': row['Review ID'], 
                'Country': row['Country'], 
                'Version': row['Version'],
                'Rating': row['Rating'],
                'Date': row['Date'],            
                'Doc Sentiment': sentiment,
                'Asp Sentiment' : '' if len(aspecttexts) > 1 else sentiment,
                'Review': review,
                'AspectText': asp,
                'Aspects': aspects[idx] if len(aspects) > idx else asp,
                'Positions': str(start_idx) + ',' + str(start_idx + len(asp) - 1),
            }, ignore_index=True)

    return df_split_terms

# %%
df_split_terms = generate_df_with_position(df)
df_split_terms.head()
# Out:
#      Review ID Country  Version Rating       Date Doc Sentiment Asp Sentiment  \
# 0  5.46424e+09  Canada  20.01.5      1 2020-01-30      negative
# 1  5.46424e+09  Canada  20.01.5      1 2020-01-30      negative
# 2  5.46699e+09     USA  20.01.5      5 2020-01-30      positive      positive
# 3  5.46055e+09     USA  20.01.4      1 2020-01-29      negative
# 4  5.46055e+09     USA  20.01.4      1 2020-01-29      negative
#
#                                               Review     Aspects AspectText  \
# 0  latest app update. this update is terrible bas...         app        app
# 1  latest app update. this update is terrible bas...     updates     update
# 2  life saver. one my favorite apps to use while ...         app       apps
# 3  worst update yet. just deleted. crashed. didn’...     updates     update
# 4  worst update yet. just deleted. crashed. didn’...  experience    deleted
#
#   Positions
# 0       7,9
# 1     11,16
# 2     28,31
# 3      6,11
# 4     23,29

# %%
len(df_split_terms)
# Out:
# 17357

# %%
df_split_terms.to_csv(r'data/qb/processed/combine_aspect_position.csv')

# %%
for index, row in df_position_sentiment.iterrows():
    if (row['Rating'] == 1 or row['Rating'] == 5) and row['Asp Sentiment'] == 0:
        df_position_sentiment.loc[index,'Asp Sentiment'] = row['Doc Sentiment']

# %%
#number of reviews without aspect
(df_position_sentiment['Asp Sentiment'].values == 0).sum()
# Out:
# 2918

# %%
#df_position_sentiment = pd.read_csv(r'./data/qb/processed/combine_aspect_position_14000.csv')

# %%
df_position_sentiment = pd.read_csv(r'./data/qb/processed/combine_aspect_position_0325_clean.csv')

# %%
df_position_sentiment = pd.read_csv(r'./data/qb/processed/combine_aspect_position_0408_nolemma_clean.csv')

# %%
df_position_sentiment['Asp Sentiment'].replace('0', np.nan, inplace=True)

# %%
df_position_sentiment.dropna(subset=['Asp Sentiment'], inplace=True)

# %%
#df_position_sentiment = df_position_sentiment.head(3000)
#(df_position_sentiment['Doc Sentiment'].values != df_position_sentiment['Asp Sentiment'].values).sum()

# %%
#df_position_sentiment.drop(
#    df_position_sentiment[df_position_sentiment['Doc Sentiment'].values == df_position_sentiment['Asp Sentiment']
#                          .values].index, inplace=True)

# %%
df_position_sentiment.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   Review ID Country  Version  \
# 0           0             0               0  5464235433  Canada  20.01.5
# 1           1             1               1  5464235433  Canada  20.01.5
# 2           2             2               2  5466985498     USA  20.01.5
# 3           3             3               3  5460552711     USA  20.01.4
# 4           4             4               4  5460552711     USA  20.01.4
#
#    Rating        Date Doc Sentiment Asp Sentiment  \
# 0       1  2020-01-30      negative       neutral
# 1       1  2020-01-30      negative      negative
# 2       5  2020-01-30      positive      positive
# 3       1  2020-01-29      negative      negative
# 4       1  2020-01-29      negative      negative
#
#                                               Review     Aspects AspectText  \
# 0  latest app update. this update is terrible bas...         app        app
# 1  latest app update. this update is terrible bas...     updates     update
# 2  life saver. one my favorite apps to use while ...         app       apps
# 3  worst update yet. just deleted. crashed. didn’...     updates     update
# 4  worst update yet. just deleted. crashed. didn’...  experience    deleted
#
#   Positions
# 0       7,9
# 1     11,16
# 2     28,31
# 3      6,11
# 4     23,29

# %%
#df_position_sentiment[df_position_sentiment.AspectText == ]
print(len(df_position_sentiment))
df_position_sentiment.dropna(subset=['AspectText'], inplace=True)
print(len(df_position_sentiment))
# Out:
# 14824
# 14821

# %%
df_position_sentiment['Asp Sentiment'].unique()
# Out:
# array(['neutral', 'negative', 'positive'], dtype=object)

# %%
#recalculate position
for index, row in df_position_sentiment.iterrows():
    
    df_position_sentiment.loc[index,'Review'] = row['Review'].replace('/', '').replace('-', '')
    
    start_idx = row['Review'].find(row['AspectText'])
          
    df_position_sentiment.loc[index,'Positions'] = str(start_idx) + ',' + str(start_idx + len(row['AspectText']) - 1)

# %%
df_position_sentiment.to_csv(r'data/qb/processed//combine_aspect_position_0408_clean_after.csv')

# %%
#df_position_sentiment[df_position_sentiment.AspectText == ]
print(len(df_position_sentiment))
df_position_sentiment.dropna(subset=['Positions'], inplace=True)
print(len(df_position_sentiment))
# Out:
# 14821
# 14821

# %%
(df_position_sentiment['Review'].str.len() <= 500).sum()
# Out:
# 14774

# %%
df_position_sentiment.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   Review ID Country  Version  \
# 0           0             0               0  5464235433  Canada  20.01.5
# 1           1             1               1  5464235433  Canada  20.01.5
# 2           2             2               2  5466985498     USA  20.01.5
# 3           3             3               3  5460552711     USA  20.01.4
# 4           4             4               4  5460552711     USA  20.01.4
#
#    Rating        Date Doc Sentiment Asp Sentiment  \
# 0       1  2020-01-30      negative       neutral
# 1       1  2020-01-30      negative      negative
# 2       5  2020-01-30      positive      positive
# 3       1  2020-01-29      negative      negative
# 4       1  2020-01-29      negative      negative
#
#                                               Review     Aspects AspectText  \
# 0  latest app update. this update is terrible bas...         app        app
# 1  latest app update. this update is terrible bas...     updates     update
# 2  life saver. one my favorite apps to use while ...         app       apps
# 3  worst update yet. just deleted. crashed. didn’...     updates     update
# 4  worst update yet. just deleted. crashed. didn’...  experience    deleted
#
#   Positions
# 0       7,9
# 1     11,16
# 2     28,31
# 3      6,11
# 4     23,29

# %%
#split data in - train test and dev
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    
    perm = np.random.permutation(np.arange(len(df)))
    m = len(df)
    
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end - 1] - 1]
    validate = df.iloc[perm[train_end:validate_end - 1] - 1]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

# %%
train, validate, test = train_validate_test_split(df_position_sentiment)

# %%
train.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 8742       8744.0        8771.0
# 17029     17233.0       17260.0
# 16246     16416.0       16443.0
# 3517       3519.0        3546.0
# 16338     16510.0       16537.0
#
#                                                Review ID  Country    Version  \
# 8742   gp:AOqpTOGCArglMaLm9qWy06RodxO2yaV0-Xxdc8FF3kf...  English  19.11.0.8
# 17029  gp:AOqpTOErhI6pc7RWzifbysMVXjGOrE9ncGtaUTJN5w9...  English        3.3
# 16246  gp:AOqpTOE7QyAWqmIhqnST3hIXOEH7LXXtIxj7_dTbG-m...  English      3.6.1
# 3517                                          1574919983      USA      5.2.2
# 16338  gp:AOqpTOFsv2ISx1GCivE4Xk8J4V6FYUjFmFLbMBGJdrn...  English        3.6
#
#        Rating        Date Doc Sentiment Asp Sentiment  \
# 8742      1.0  2019-12-23      negative      negative
# 17029     5.0  2013-10-09      positive      positive
# 16246     5.0  2014-08-14      positive      positive
# 3517      4.0  2017-03-28      positive      positive
# 16338     4.0  2014-07-12      positive      positive
#
#                                                   Review     Aspects  \
# 8742   . why can't i see bank account details in the ...  experience
# 17029  . full featured app! quickbooks makes it easy ...   invoicing
# 16246  great app. no longer have to worry about compu...         app
# 3517   great app. very easy to use. reliable. every o...         app
# 16338  pretty convenient!. i quite like being able to...         app
#
#       AspectText Positions
# 8742     useless   163,169
# 17029   invoices   128,135
# 16246        app       6,8
# 3517         app       6,8
# 16338        app     83,85

# %%
print(len(train))
print(len(test))
print(len(validate))
# Out:
# 8891
# 2965
# 2963

# %% [markdown]
# ### Generate files

# %%
def generate_input_files(d_type, data):

    #save reviews
    df_review = data[['Review']]
    df_review.to_csv(r'data/qb/{}/review.txt'.format(d_type), header=None, index=None, sep='\n', mode='a')

    #save aspects
    df_review = data[['AspectText']]
    df_review.to_csv(r'data/qb/{}/term.txt'.format(d_type), header=None, index=None, sep='\n', mode='a')

    #save positions
    df_review = data[['Positions']]
    df_review.to_csv(r'data/qb/{}/position.txt'.format(d_type), header=None, index=None, sep='\n', mode='a')

    #save label
    df_review = data[['Asp Sentiment']]
    df_review.to_csv(r'data/qb/{}/label.txt'.format(d_type), header=None, index=None, sep='\n', mode='a')

# %%
generate_input_files('train', train)
generate_input_files('test', test)
generate_input_files('dev', validate)
